# %%
import tensorflow as tf
import sys, os
sys.path.append(os.path.abspath(os.path.join('../data_file')))
from data_file.processing import Dataset
import matplotlib.pyplot as plt

# %%
dataset = Dataset(path="../data/", batch_size=8, big_endian=False)
dataset.setup()
train_ds, valid_ds, test_ds = dataset.train_ds, dataset.valid_ds, dataset.test_ds

# %%
for x, y in train_ds.take(1):
    for i in range(8):
        z = y[i] - x[i]
        plt.imshow(z, cmap='gray')
        plt.show()

# %%
import tensorflow as tf
def discriminator_loss(y_true_disc,y_pred_disc):
    """
    y_true are the true label : 1 for real image and 0 for fake image
    y_pred is the output of the discriminator # (bs, 1)
    """
    return -tf.reduce_mean( tf.math.log(1- y_pred_disc) +  tf.math.log(y_true_disc), axis=0)[0]


x = tf.random.uniform((3,1))
y = tf.random.uniform((3,1))

print(discriminator_loss(x,y))
# Out:
# 2023-02-14 14:09:21.659582: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tf.Tensor(1.7281939, shape=(), dtype=float32)
# 2023-02-14 14:09:26.472025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
