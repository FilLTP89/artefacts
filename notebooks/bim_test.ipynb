# %%
from PIL import Image
import os
import random
import numpy as np
import matplotlib.pyplot as plt

DATA_PATH = "../data/Difference/"

# %%
random_file = random.choice(os.listdir(DATA_PATH))
img = Image.open( DATA_PATH + random_file)
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=296x294>

# %%
array = np.array(img)
array.shape
# Out:
# (294, 296)
