# %%
import os
from PIL import Image
import numpy as np
import cv2
import sys
sys.path.append("../")
from data_file.CBCT_preprocess import read_raw
import matplotlib.pyplot as plt

# %%
file = "ground_truth0821.raw"
array = read_raw(file, (512,512))

# %%
array.shape # 512x512
# Out:
# (512, 512)

# %%
plt.imshow(array,cmap="gray")
